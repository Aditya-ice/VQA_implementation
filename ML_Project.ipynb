# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditya-ice/VQA_implementation/blob/main/ML_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Set up environment

# %%
# !git clone https://github.com/salesforce/LAVIS.git
# %cd LAVIS

# Install in editable mode
# !pip install -e .

# (if open3d version throws errors)
# !sed -i 's/open3d==0.13.0/open3d>=0.13.0/' requirements.txt
# Out:
# Cloning into 'LAVIS'...
# remote: Enumerating objects: 7834, done.
# remote: Counting objects: 100% (2407/2407), done.
# remote: Compressing objects: 100% (329/329), done.
# remote: Total 7834 (delta 2129), reused 2078 (delta 2078), pack-reused 5427 (from 2)
# Receiving objects: 100% (7834/7834), 88.19 MiB | 32.72 MiB/s, done.
# Resolving deltas: 100% (5097/5097), done.
# /content/LAVIS
# Obtaining file:///content/LAVIS
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.4/235.4 kB 17.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# !pip install numpy==1.23.5 --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 93.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.23.5 which is incompatible.
# chex 0.1.89 requires numpy>=1.24.1, but you have numpy 1.23.5 which is incompatible.
# xarray 2025.1.2 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# bigframes 1.42.0 requires numpy>=1.24.0, but you have numpy 1.23.5 which is incompatible.
# albumentations 2.0.5 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# scikit-image 0.25.2 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# jax 0.5.2 requires numpy>=1.25, but you have numpy 1.23.5 which is incompatible.
# albucore 0.0.23 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# ...

# %%
# !pip install transformers==4.26.1 --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 20.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 46.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 3.4.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.26.1 which is incompatible.

# %%
# !pip install peft==0.3.0 --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 79.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 64.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 61.9 MB/s eta 0:00:00
# ...

# %%
# !pip install huggingface_hub==0.24.5 --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.5/417.5 kB 16.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 3.4.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.26.1 which is incompatible.

# %%
# !pip install fairscale==0.4.4 --quiet
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# !pip install iopath==0.1.10 --quiet
# Out:
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !pip install fvcore --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !pip install timm --quiet

# %%
# !pip install decord --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 54.7 MB/s eta 0:00:00

# %%
# !pip install webdataset --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 kB 4.6 MB/s eta 0:00:00

# %%
# !pip install opencv-python --quiet

# %%
# !pip install sentencepiece --quiet

# %%
# !pip install pycocoevalcap --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 8.5 MB/s eta 0:00:00

# %%
# !pip install omegaconf --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 2.7 MB/s eta 0:00:00
# ...

# %%
# !pip install jax==0.4.6 --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 31.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chex 0.1.89 requires jax>=0.4.27, but you have jax 0.4.6 which is incompatible.
# chex 0.1.89 requires numpy>=1.24.1, but you have numpy 1.23.5 which is incompatible.
# orbax-checkpoint 0.11.12 requires jax>=0.5.0, but you have jax 0.4.6 which is incompatible.
# optax 0.2.4 requires jax>=0.4.27, but you have jax 0.4.6 which is incompatible.
# flax 0.10.5 requires jax>=0.5.1, but you have jax 0.4.6 which is incompatible.

# %%
# !pip install jaxlib==0.4.6 --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 MB 10.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chex 0.1.89 requires jax>=0.4.27, but you have jax 0.4.6 which is incompatible.
# chex 0.1.89 requires jaxlib>=0.4.27, but you have jaxlib 0.4.6 which is incompatible.
# chex 0.1.89 requires numpy>=1.24.1, but you have numpy 1.23.5 which is incompatible.
# optax 0.2.4 requires jax>=0.4.27, but you have jax 0.4.6 which is incompatible.
# optax 0.2.4 requires jaxlib>=0.4.27, but you have jaxlib 0.4.6 which is incompatible.
# flax 0.10.5 requires jax>=0.5.1, but you have jax 0.4.6 which is incompatible.

# %% [markdown]
# # Load an example image and question

# %%
import sys
sys.path.append("/content/LAVIS")

# %%
import torch
import requests
from PIL import Image
from matplotlib import pyplot as plt
import numpy as np

from lavis.common.gradcam import getAttMap
from lavis.models import load_model_and_preprocess
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-3946b9fac63c> in <cell line: 0>()
#       5 import numpy as np
#       6
# ----> 7 from lavis.common.gradcam import getAttMap
#       8 from lavis.models import load_model_and_preprocess
#
# /content/LAVIS/lavis/__init__.py in <module>
#      13 from lavis.common.registry import registry
#      14
# ---> 15 from lavis.datasets.builders import *
#      16 from lavis.models import *
#      17 from lavis.processors import *
#
# /content/LAVIS/lavis/datasets/builders/__init__.py in <module>
#       6 """
#       7
# ----> 8 from lavis.datasets.builders.base_dataset_builder import load_dataset_config
#       9 from lavis.datasets.builders.caption_builder import (
#      10     COCOCapBuilder,
#
# /content/LAVIS/lavis/datasets/builders/base_dataset_builder.py in <module>
#      11 import warnings
#      12
# ...

# %%
# img_url = 'https://storage.googleapis.com/sfr-vision-language-research/LAVIS/projects/pnp-vqa/demo.png'
img_url = '/content/LAVIS/test1oil.jpg'
# raw_image = Image.open(requests.get(img_url, stream=True).raw).convert('RGB')
raw_image = Image.open(img_url).convert('RGB')
# raw_image = Image.open("./demo.png").convert("RGB")
display(raw_image.resize((400, 300)))
question = "How many industrail level large storage tanks are there?"
print(question)

# %%
# setup device to use
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device

# %% [markdown]
# # Load PNP-VQA model

# %%
model, vis_processors, txt_processors = load_model_and_preprocess(name="pnp_vqa", model_type="base", is_eval=True, device=device)

# %% [markdown]
# # Preprocess image and text inputs

# %%
image = vis_processors["eval"](raw_image).unsqueeze(0).to(device)
question = txt_processors["eval"](question)

samples = {"image": image, "text_input": [question]}

# %% [markdown]
# # PNP-VQA utilizes 3 submodels to perform VQA:

# %% [markdown]
# ## 1. Image-Question Matching
# Compute the relevancy score of image patches with respect to the question using GradCAM

# %%
samples = model.forward_itm(samples=samples)

# %%
# Gradcam visualisation
dst_w = 720
w, h = raw_image.size
scaling_factor = dst_w / w

resized_img = raw_image.resize((int(w * scaling_factor), int(h * scaling_factor)))
norm_img = np.array(resized_img).astype(np.float32) / 255.0
gradcam = samples['gradcams'].reshape(24, 24).cpu().detach().numpy()

avg_gradcam = getAttMap(norm_img, gradcam, blur=True)

fig, ax = plt.subplots(1, 1, figsize=(5, 5))
ax.imshow(avg_gradcam)
ax.set_yticks([])
ax.set_xticks([])
print('Question: {}'.format(question))
# Out:
# Question: is there more than 5 storage tanks there and also oil burning signs?

# %% [markdown]
# ## 2. Image Captioning
# Generate question-guided captions based on the relevancy score

# %%
samples = model.forward_cap(samples=samples, num_captions=50, num_patches=20)
print('Examples of question-guided captions: ')
samples['captions'][0][:5]
# Out:
# Examples of question-guided captions:
# ['an fire a gas top oil iraq, drone iraq satellite air aerial an an satellite',
#  'the oil tanks on the building are the same shape as the tanks',
#  'oil fire factory a an flames fire smoke fire an flames an black burning an fire',
#  'the tanks are all a bomb with a lot of black and red objects',
#  'bombs are seen on top of a power pole']

# %% [markdown]
# ## 3. Question Answering
# Answer the question by using the captions

# %%
pred_answers = model.forward_qa(samples, num_captions=50)
print('Question: {} \nPredicted answer: {}'.format(question, pred_answers[0]))
# Out:
# Question: is there more than 5 storage tanks there and also oil burning signs?
# Predicted answer: yes

# %% [markdown]
# # Generate answer by calling predict_answers() directly

# %%
pred_answers, caption, gradcam = model.predict_answers(samples, num_captions=50, num_patches=20)
print('Question: {} \nPredicted answer: {}'.format(question, pred_answers[0]))
# Out:
# Question: is there more than 5 storage tanks there and also oil burning signs?
# Predicted answer: yes
